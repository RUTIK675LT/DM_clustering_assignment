# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/RUTIK675LT/DM_clustering_assignment/blob/main/2%20Hierarchical%20clustering/b_Hierarchical_clustering.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# Load the dataset
# Replace 'your_hierarchical_dataset.csv' with the path to the dataset CSV file
df = pd.read_csv('/content/hierarchical_clustering_dataset.csv')
points = df.values

# Perform hierarchical clustering
Z = linkage(points, method='ward')

# Plotting the dendrogram
plt.figure(figsize=(10, 7))
plt.title('Hierarchical Clustering Dendrogram')
dendrogram(Z)
plt.xlabel('Data points')
plt.ylabel('Euclidean distance')
plt.show()
